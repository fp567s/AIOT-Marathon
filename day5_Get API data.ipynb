# %%
#作業1 : 練習使用一個民生物聯網 API，例如空氣、地震等感測站所回傳的紀錄資料。

# %%
import pprint

# URL for the API
url = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/"

# POST the request to the server
response = requests.get(url)
# GET the response from the server and grab the json
result = response.json()

# Using pprint to show the beauty format
# You can use print also
pprint.pprint(result)
# Out:
# {'value': [{'name': 'Datastreams',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Datastreams'},
#            {'name': 'MultiDatastreams',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/MultiDatastreams'},
#            {'name': 'FeaturesOfInterest',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/FeaturesOfInterest'},
#            {'name': 'HistoricalLocations',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/HistoricalLocations'},
#            {'name': 'Locations',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Locations'},
#            {'name': 'Observations',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations'},
#            {'name': 'ObservedProperties',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/ObservedProperties'},
#            {'name': 'Sensors',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Sensors'},
#            {'name': 'Things',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things'}]}

# %%
#作業2 : 練習操作 OGC SensorThings API，將環保局測站位置的資料抓取下來，並且觀察下載資料的內容。
#           參考網址：https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things

# %%
import pprint

# URL for the API
url = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things"

# POST the request to the server
response = requests.get(url)
# GET the response from the server and grab the json
data = response.json()

# Using pprint to show the beauty format
# You can use print also
#pprint.pprint(result)

# Get the amount of data
print("The total amount of data is {}.".format(data["@iot.count"]))

# Get @iot.nextLink
print("The total amount of data is {}.".format(data["@iot.nextLink"]))
# Out:
# The total amount of data is 9703.
# The total amount of data is https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things?$skip=100.

# %%
#作業3 : 依據作業 2 所下載的各個環保局測站感測器的描述資料，進一步點選 Datastreams、Locations，
#以及 Datastreams 點選進入後，點選 Observations 的 URL，觀察所下載到的資料內容，
#其中 Observations 內部是否包含個別感測器紀錄的資料

# %%
# Get the detail of each value
value = data["value"]
print("\nThere are {} data in this page".format(len(value)))

len_data= len(value)
for i in range(len_data):
    print("=============data {}=============".format(value[i]["@iot.id"]))
    print("Description:", value[i]["description"])
     # You can print set up your own data
# Out:
# There are 100 data in this page
# =============data 1=============
# Description: 智慧城鄉空品微型感測器-11113765144
# =============data 2=============
# Description: 智慧城鄉空品微型感測器-11183695772
# =============data 3=============
# Description: 智慧城鄉空品微型感測器-9330689794
# =============data 4=============
# Description: 智慧城鄉空品微型感測器-7518931416
# =============data 5=============
# Description: 智慧城鄉空品微型感測器-10054926614
# =============data 6=============
# Description: 智慧城鄉空品微型感測器-8934297298
# =============data 7=============
# Description: 智慧城鄉空品微型感測器-8983494557
# =============data 8=============
# Description: 智慧城鄉空品微型感測器-9045855956
# =============data 9=============
# Description: 智慧城鄉空品微型感測器-11181974894
# =============data 10=============
# Description: 智慧城鄉空品微型感測器-9045719838
# =============data 11=============
# Description: 智慧城鄉空品微型感測器-7516777282
# =============data 12=============
# Description: 智慧城鄉空品微型感測器-6766983971
# =============data 13=============
# Description: 智慧城鄉空品微型感測器-7482648903
# =============data 14=============
# Description: 智慧城鄉空品微型感測器-6821802292
# =============data 15=============
# Description: 智慧城鄉空品微型感測器-6793570925
# =============data 16=============
# Description: 智慧城鄉空品微型感測器-8982111706
# =============data 17=============
# Description: 智慧城鄉空品微型感測器-9277760172
# =============data 18=============
# Description: 智慧城鄉空品微型感測器-7499623611
# =============data 19=============
# Description: 智慧城鄉空品微型感測器-10344320880
# =============data 20=============
# Description: 智慧城鄉空品微型感測器-6898932900
# =============data 21=============
# Description: 智慧城鄉空品微型感測器-10050409070
# =============data 22=============
# Description: 智慧城鄉空品微型感測器-11183763722
# =============data 23=============
# Description: 智慧城鄉空品微型感測器-6171766699
# =============data 24=============
# Description: 智慧城鄉空品微型感測器-9062285743
# =============data 25=============
# Description: 智慧城鄉空品微型感測器-9272298145
# =============data 26=============
# Description: 智慧城鄉空品微型感測器-10905752878
# =============data 27=============
# Description: 智慧城鄉空品微型感測器-11176961948
# =============data 28=============
# Description: 智慧城鄉空品微型感測器-10200485379
# =============data 29=============
# Description: 智慧城鄉空品微型感測器-10294451686
# =============data 30=============
# Description: 智慧城鄉空品微型感測器-9275897800
# =============data 31=============
# Description: 智慧城鄉空品微型感測器-10058258806
# =============data 32=============
# Description: 智慧城鄉空品微型感測器-9998190634
# =============data 33=============
# Description: 智慧城鄉空品微型感測器-6784992768
# =============data 34=============
# Description: 智慧城鄉空品微型感測器-11204227572
# =============data 35=============
# Description: 智慧城鄉空品微型感測器-10065446652
# =============data 36=============
# Description: 智慧城鄉空品微型感測器-9307698703
# =============data 37=============
# Description: 智慧城鄉空品微型感測器-6230748013
# =============data 38=============
# Description: 智慧城鄉空品微型感測器-9385545028
# =============data 39=============
# Description: 智慧城鄉空品微型感測器-6764352442
# =============data 40=============
# Description: 智慧城鄉空品微型感測器-6819510321
# =============data 41=============
# Description: 智慧城鄉空品微型感測器-10220778450
# =============data 42=============
# Description: 智慧城鄉空品微型感測器-6957015512
# =============data 43=============
# Description: 智慧城鄉空品微型感測器-9066805738
# =============data 44=============
# Description: 智慧城鄉空品微型感測器-8959673007
# =============data 45=============
# Description: 智慧城鄉空品微型感測器-6785566738
# =============data 46=============
# Description: 智慧城鄉空品微型感測器-7732269222
# =============data 47=============
# Description: 智慧城鄉空品微型感測器-6898625380
# =============data 48=============
# Description: 智慧城鄉空品微型感測器-8959504634
# =============data 49=============
# Description: 智慧城鄉空品微型感測器-7661934054
# =============data 50=============
# Description: 智慧城鄉空品微型感測器-10243744003
# =============data 51=============
# Description: 智慧城鄉空品微型感測器-10764638242
# =============data 52=============
# Description: 智慧城鄉空品微型感測器-10759750620
# =============data 53=============
# Description: 智慧城鄉空品微型感測器-11128928500
# =============data 54=============
# Description: 智慧城鄉空品微型感測器-10417846834
# =============data 55=============
# Description: 智慧城鄉空品微型感測器-9348517248
# =============data 56=============
# Description: 智慧城鄉空品微型感測器-9384363838
# =============data 57=============
# Description: 智慧城鄉空品微型感測器-6794149209
# =============data 58=============
# Description: 智慧城鄉空品微型感測器-6778502244
# =============data 59=============
# Description: 智慧城鄉空品微型感測器-10049456087
# =============data 60=============
# Description: 智慧城鄉空品微型感測器-9262880023
# =============data 61=============
# Description: 智慧城鄉空品微型感測器-9270182381
# =============data 62=============
# Description: 智慧城鄉空品微型感測器-6173417043
# =============data 63=============
# Description: 智慧城鄉空品微型感測器-6798985336
# =============data 64=============
# Description: 智慧城鄉空品微型感測器-9085165826
# =============data 65=============
# Description: 智慧城鄉空品微型感測器-10038100708
# =============data 66=============
# Description: 智慧城鄉空品微型感測器-6825443564
# =============data 67=============
# Description: 智慧城鄉空品微型感測器-10911255654
# =============data 68=============
# Description: 智慧城鄉空品微型感測器-10579543028
# =============data 69=============
# Description: 智慧城鄉空品微型感測器-10111913649
# =============data 70=============
# Description: 智慧城鄉空品微型感測器-11105419263
# =============data 71=============
# Description: 智慧城鄉空品微型感測器-11200349532
# =============data 72=============
# Description: 智慧城鄉空品微型感測器-11108401536
# =============data 73=============
# Description: 智慧城鄉空品微型感測器-6795150792
# =============data 74=============
# Description: 智慧城鄉空品微型感測器-6245846003
# =============data 75=============
# Description: 智慧城鄉空品微型感測器-6959534665
# =============data 76=============
# Description: 智慧城鄉空品微型感測器-9045281936
# =============data 77=============
# Description: 智慧城鄉空品微型感測器-9068187062
# =============data 78=============
# Description: 智慧城鄉空品微型感測器-11149863121
# =============data 79=============
# Description: 智慧城鄉空品微型感測器-11190330165
# =============data 80=============
# Description: 智慧城鄉空品微型感測器-9311975594
# =============data 81=============
# Description: 智慧城鄉空品微型感測器-10105964051
# =============data 82=============
# Description: 智慧城鄉空品微型感測器-9322309861
# =============data 83=============
# Description: 智慧城鄉空品微型感測器-11103295169
# =============data 84=============
# Description: 智慧城鄉空品微型感測器-9343933573
# =============data 85=============
# Description: 智慧城鄉空品微型感測器-10326302834
# =============data 86=============
# Description: 智慧城鄉空品微型感測器-11099395240
# =============data 87=============
# Description: 智慧城鄉空品微型感測器-6944202150
# =============data 88=============
# Description: 智慧城鄉空品微型感測器-6203673165
# =============data 89=============
# Description: 智慧城鄉空品微型感測器-6848216472
# =============data 90=============
# Description: 智慧城鄉空品微型感測器-9021298375
# =============data 91=============
# Description: 智慧城鄉空品微型感測器-10051729680
# =============data 92=============
# Description: 智慧城鄉空品微型感測器-10215328840
# =============data 93=============
# Description: 智慧城鄉空品微型感測器-8953787317
# =============data 94=============
# Description: 智慧城鄉空品微型感測器-7503698866
# =============data 95=============
# Description: 智慧城鄉空品微型感測器-6798699508
# =============data 96=============
# Description: 智慧城鄉空品微型感測器-7516433187
# =============data 97=============
# Description: 智慧城鄉空品微型感測器-6831118249
# =============data 98=============
# Description: 智慧城鄉空品微型感測器-6221795973
# =============data 99=============
# Description: 智慧城鄉空品微型感測器-6219300143
# =============data 100=============
# Description: 智慧城鄉空品微型感測器-10246506970
